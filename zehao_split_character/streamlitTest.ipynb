# %% [markdown]
# # Imports

# %%
import streamlit as st
import numpy as np
import cv2
import os

# %% [markdown]
# ## Import utils

# %%
import sys, os
# Detect current working directory safely
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add parent folder to Python path
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
from utils import data_previewer, DataObject, img_preprocessing

# %%
if 'data' not in st.session_state:
    st.session_state.data = []
    data = st.session_state.data

    # Loop through all png in train/
    for (root,dirs,files) in os.walk('../train/',topdown=True):
        for file in files:
            if file.endswith('.png'):
                img_path = os.path.join(root, file)
                img = cv2.imread(img_path)
                processed_img = img_preprocessing(img)
                ground_truth = img_path.split("-")[0].split("/")[-1] 
                prediction = "Example Prediction"  # Placeholder
                data.append(DataObject(img, processed_img, ground_truth, prediction))

data_previewer(st.session_state.data)
# Out:
# 2025-10-19 21:08:45.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-19 21:08:45.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
